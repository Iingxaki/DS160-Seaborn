# %% [markdown]
# # Python Seaborn

# %% [markdown]
# ## What is Seaborn?
#
# - Python Data Visualization Library - based on MatPlotLib
# - Used for plotting statistical graphs, identifying trends, relationships & outliers
# - Seaborn is easier & faster to use (less code) Vs MatPlotLib
# - https://seaborn.pydata.org/
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Seaborn plots
# - Trend Plots:
#     - Line Plots
#
#
# - Summary Plots:
#     - Bar Plots
#
#
# - Distribution of Data:
#     - Histogram
#     - Box Plots
#
#
# - Relationship Plots
#     - Scatter Plots
#     - Swarm Plots
#     - lmplot (combo of regplot() and FacetGrid)
#
#
# - Holistic views / Combo:
#     - Pair Plots
#     - Join Plots
#
#
# - Correlation / Relationships:
#     - Heat Maps

# %% [markdown]
# ## Importing / Installing packages

# %%
#!pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Loading the Raw Data

# %%
raw_data=pd.read_csv('Marketing.csv')

# %%
raw_data.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             182 non-null    object
#  1   Week             182 non-null    int64
#  2   Week_ID          182 non-null    int64
#  3   Month            182 non-null    int64
#  4   Month_ID         182 non-null    int64
#  5   Year             182 non-null    int64
#  6   Day_Name         182 non-null    object
#  7   Visitors         182 non-null    int64
#  8   Revenue          182 non-null    int64
#  9   Marketing Spend  182 non-null    float64
#  10  Promo            182 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ## 2. Line chart
# ### Line chart is one of the most common and basic type of visualization used for visualizing continuous values against continuous variable such as time, distance, speed etc. It’s best suited for visualizing data with chronological trends. It can be used to compare the change between two or more groups.
# seaborn.lineplot(*, x=None, y=None, hue=None, size=None, style=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, units=None, estimator='mean', ci=95, n_boot=1000, seed=None, sort=True, err_style='band', err_kws=None, legend='auto', ax=None, **kwargs)
# * The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters.
# * https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
# Example 1 - Simple 1 line graph
# Assuming we want to investigate the Revenue by Week_ID
sns.lineplot(x='Week_ID',y='Revenue',data=raw_data)
# Notes: error bands show the confidence interval
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Example 2 - Add another dimension (Promo)
#the hue parameter represents which column in the data frame, you want to use for color encoding.
sns.lineplot(x='Week_ID',y='Revenue',data=raw_data, hue='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lineplot(x='Week_ID',y='Revenue',data=raw_data, hue='Day_Name')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Example 3 - By Promo with style
sns.lineplot(x='Week_ID',y='Revenue',data=raw_data,hue='Promo',style='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Example 4 - By Promo with style & Increase the size & Remove error bars

# increase the size
sns.set(rc={'figure.figsize':(12,10)})
sns.lineplot(x='Week_ID',y='Revenue',data=raw_data,hue='Promo',style='Promo',ci=False)
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_2608\2014546920.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x='Week_ID',y='Revenue',data=raw_data,hue='Promo',style='Promo',ci=False)
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## 3. Bar Plots
# ### Bar plot can be defined as a visualization method that represents a group through rectangular vertical bars in X axis by their actions in Y-axis. Usually, the aggregate of the categorical variable to be plotted is represented in the x-axis and their aggregate numerical value is represented in the y-axis.
# seaborn.barplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x7ff320f315e0>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)
# * Show point estimates and confidence intervals as rectangular bars.
# * https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
raw_data=pd.read_csv('Marketing.csv')
raw_data.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
# Example 1 - Total Revenue by Month
sns.barplot(x='Month',y='Revenue',data=raw_data)

# Notes: 
#the lines signify the confidence interval
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Month', ylabel='Revenue'>

# %%
# Example 2 - Total Revenue by Month - Remove the Confidence Interval
sns.barplot(x='Month',y='Revenue',data=raw_data,ci=False)
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_2608\2994119846.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Month',y='Revenue',data=raw_data,ci=False)
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Example 3 - Total Revenue by Month - Remove the Confidence Interval - By Promo
sns.barplot(x='Month',y='Revenue',data=raw_data,ci=False,hue='Promo')
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_2608\3423243421.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Month',y='Revenue',data=raw_data,ci=False,hue='Promo')
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Example 4 - Total Revenue by Year - Remove the Confidence Interval - By Promo - Changing direction
sns.barplot(x='Revenue',y='Month',data=raw_data,ci=False,hue='Promo',orient='h')
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_2608\3213879277.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Revenue',y='Month',data=raw_data,ci=False,hue='Promo',orient='h')
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## 4. Histograms
# ### histogram is an approximate representation of the distribution of numerical data.
# seaborn.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)¶

# %%
raw_data = pd.read_csv("Marketing.csv")
raw_data.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             182 non-null    object
#  1   Week             182 non-null    int64
#  2   Week_ID          182 non-null    int64
#  3   Month            182 non-null    int64
#  4   Month_ID         182 non-null    int64
#  5   Year             182 non-null    int64
#  6   Day_Name         182 non-null    object
#  7   Visitors         182 non-null    int64
#  8   Revenue          182 non-null    int64
#  9   Marketing Spend  182 non-null    float64
#  10  Promo            182 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 15.8+ KB

# %%
# Example 1 - Investigating the distribution of Revenue
sns.histplot(x='Revenue',data=raw_data)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Revenue', ylabel='Count'>

# %%
# dist plot (distribution of data set)
#sns.distplot(x='Revenue',data=raw_data)

# %%
# Example 2 - Investigating the distribution of Revenue, adding the mean
sns.histplot(x='Revenue',data=raw_data)

# Calculating the mean
mean=raw_data['Revenue'].mean()
print(mean)
#ploting the mean
plt.axvline(mean,color='Red')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 10581.593406593407

# %%
# Example 3 - Investigating the distribution of Visitors, adding the mean,median
sns.histplot(x='Visitors',data=raw_data)

# Calculating the mean
mean=raw_data['Visitors'].mean()
print(mean)
#ploting the mean
plt.axvline(mean,color='Red')
# Calculating the mean
median=raw_data['Visitors'].median()
print(median)
#ploting the mean
plt.axvline(median,color='Yellow')
# Out:
# 1666.7307692307693
# 1546.0
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 5. Box Plots
# ### A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
# seaborn.boxplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)¶
# ![image.png](attachment:image.png)

# %%
raw_data = pd.read_csv("Marketing.csv")
raw_data.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0   9/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
# Example 1 - Investigating the distribution of Revenue
sns.boxplot(x='Revenue',data=raw_data)
raw_data['Revenue'].describe()
# Notes:
# The line signifies the median
# The box in the middle show the beginning of Q1 (25th percentile) and the end of the Q3 (75th percentile)
# The whiskers (left - right) show the minimum quartile and maximum quartile
# The dots on the right are "outliers"
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# count      182.000000
# mean     10581.593407
# std       6297.626426
# min        292.000000
# 25%       5929.500000
# 50%       9452.000000
# 75%      12959.500000
# max      36283.000000
# Name: Revenue, dtype: float64

# %%
# Example 2 - Investigating the distribution of Revenue by Day
sns.boxplot(x='Day_Name',y='Revenue',data=raw_data)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Day_Name', ylabel='Revenue'>

# %%
# Example 3 - Investigating the distribution of 
#Revenue by Day - Horizontal - change color
sns.boxplot(y='Day_Name',x='Revenue',data=raw_data,color='#33FF86')

# Cool Way to pick colours
# https://htmlcolorcodes.com/color-picker/
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Revenue', ylabel='Day_Name'>

# %% [markdown]
# ### More on Boxplots here:
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %% [markdown]
# ## 6. ScatterPlots
# ### The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters. These parameters control what visual semantics are used to identify the different subsets.
# seaborn.scatterplot(*, x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha=None, x_jitter=None, y_jitter=None, legend='auto', ax=None, **kwargs)¶

# %%
# df columns
raw_data = pd.read_csv("Marketing.csv")

raw_data.columns
# Out:
# Index(['Date', 'Week', 'Week_ID', 'Month', 'Month_ID', 'Year', 'Day_Name',
#        'Visitors', 'Revenue', 'Marketing Spend', 'Promo'],
#       dtype='object')

# %%
# Example 1 - Relationship between Marketing Spend and Revenue
sns.scatterplot(x='Marketing Spend',y='Revenue',data=raw_data)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Marketing Spend', ylabel='Revenue'>

# %%
# Example 2 - Relationship between Marketing Spend and Revenue - changing color, hue & Style to catagorical
sns.scatterplot(x='Marketing Spend',y='Revenue',data=raw_data,hue='Promo',style='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## 6a. Swarmplot
# ### Swarm Plot in Seaborn is used to draw a categorical scatterplot with non-overlapping points.
# seaborn.swarmplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)¶

# %%
#Day_Name vs Revenue
sns.swarmplot(x='Day_Name',y='Revenue',data=raw_data)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.set(rc={'figure.figsize':(12,10)})
sns.swarmplot(x='Marketing Spend',y='Revenue',data=raw_data,hue='Day_Name')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## 7. lmPlots
# ### It is used to draw a scatter plot onto a FacetGrid.
# #### facetGrid useful approach to explore medium-dimensional data, is by drawing multiple instances of the same plot on different subsets of your dataset.
# * seaborn.lmplot(*, x=None, y=None, data=None, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=None, sharey=None, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, facet_kws=None, size=None)¶

# %%
# Example 1 - Relationship between Marketing Spend and Revenue
raw_data=pd.read_csv('Marketing.csv')
raw_data.head()

sns.lmplot(x='Marketing Spend',y='Revenue',data=raw_data)


# Notes:
# What is Linear Regression: It is a predictive statistical method for modelling the relationship between x (independent variable) & y (dependent V).
# How it works (cost function MSE): https://towardsdatascience.com/machine-learning-fundamentals-via-linear-regression-41a5d11f5220
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Example 2 - Relationship between Marketing Spend and Revenue , remove errorbar, add hue & Style
sns.lmplot(x='Marketing Spend',y='Revenue',data=raw_data,ci=False,hue='Promo',markers=['o','x','+'])
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Example 3 - Relationship between Marketing Spend and Revenue - by column
sns.lmplot(x='Marketing Spend',y='Revenue',data=raw_data,ci=False,hue='Promo',markers=['o','x','+'],col='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#-Relationship between Marketing Spend and Revenue - by column, hue =Day_Name
sns.lmplot(x='Marketing Spend',y='Revenue',data=raw_data,ci=False,hue='Day_Name',markers=['o','x','+','o','x','+','o'], col='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 8. Pairplots
# ### Pairplot uses to get the relation between each and every variable present in Pandas DataFrame. It works like a seaborn scatter plot but it plot only two variables plot and sns paiplot plot the pairwise plot of multiple features/variable in a grid format.
# seaborn.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)¶

# %%
# Example 1 - running on all dataframe 
raw_data = pd.read_csv("Marketing.csv")
sns.pairplot(raw_data)
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Example 2 - running on specific columns - adding hue
sns.pairplot(raw_data[['Revenue','Marketing Spend','Visitors','Promo']],hue='Promo')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### More on Pairplots:
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# ## 9. JointPlots
# ### Seaborn’s jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins.
# #### Draw a plot of two variables with bivariate and univariate graphs.
# seaborn.jointplot(*, x=None, y=None, data=None, kind='scatter', color=None, height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, hue=None, palette=None, hue_order=None, hue_norm=None, **kwargs)¶

# %%
# Example 1 - Revenue vs marketing Spend Relationship with 
sns.jointplot(x='Revenue',y='Marketing Spend',data=raw_data,kind='reg')
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## 11. Heat Map
# ### A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.
# *  .corr() is used to find the pairwise correlation of all columns in the dataframe. Any null values are automatically excluded
# *  The closer to 1 or -1 the better. As one variable increases, the other variable tends to also increase / decrease
# * More Info here: https://statisticsbyjim.com/basics/correlations/
# seaborn.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)¶

# %%
# Example 1 - Heatmap for PC
heat_map=raw_data[['Revenue','Marketing Spend','Visitors']].corr()
cols=['Revenue','Marketing Spend','Visitors']

print(heat_map)
sns.heatmap(heat_map,xticklabels=cols, yticklabels=cols,annot=True)
# Out:
#                   Revenue  Marketing Spend  Visitors
# Revenue          1.000000         0.790425  0.573842
# Marketing Spend  0.790425         1.000000  0.824810
# Visitors         0.573842         0.824810  1.000000
# <Axes: >

# %%
# Example 2 - Heatmap for PC - changing cmap
heat_map=raw_data[['Revenue','Marketing Spend','Visitors']].corr()
cols=['Revenue','Marketing Spend','Visitors']

print(heat_map)
sns.heatmap(heat_map,xticklabels=cols, yticklabels=cols,annot=True,cmap='Greens')




# Examples:
# cmap="YlGnBu"
# cmap="Blues"
# cmap="BuPu"
# cmap="Greens"
# Out:
#                   Revenue  Marketing Spend  Visitors
# Revenue          1.000000         0.790425  0.573842
# Marketing Spend  0.790425         1.000000  0.824810
# Visitors         0.573842         0.824810  1.000000
# <Axes: >

# %% [markdown]
# ### More details for Heatmaps here:
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# # Subplots

# %%
#create scatter plot for Revenue vs Visitors 
fig,axes= plt.subplots(2,2,figsize=(12,8)) #2 row and 2 column
# create scatter plot for Revenue vs Visitors 
sns.scatterplot(x='Revenue', y= 'Visitors', data= raw_data, ax=axes[0,0])

# Create bar plot for day_name vs Revenue
sns.barplot(x='Day_Name',y='Revenue', data=raw_data, ax=axes[0,1])

# Create histogram for Revenue 
sns.histplot(x='Revenue', data=raw_data, ax=axes[1,0])

# Create line plot for Week_ID vs Revenue
sns.lineplot(x='Week_ID',y='Revenue', data=raw_data, ax=axes[1,1])
# Out:
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rhukom\.conda\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
